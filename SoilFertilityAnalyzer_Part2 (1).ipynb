# %%
import pandas as pd

# %%
df=pd.read_excel("soil.xlsx")
df.isna().sum()
# Out:
# Sr. No.               9
# Report Number         8
# Farmer Name           8
# Village               8
# Variety               8
# Plot No/\nGat No     37
# Area (Acres)        503
# Sample Date           8
# Report Date           8
# pH                    8
# EC                    8
# CaCo3                 8
# OC                    8
# N                     8
# NH4-N                 8
# P                     8
# K                     8
# Ca                    8
# Mg                    8
# S                     8
# Fe                    8
# Mn                    8
# Zn                    8
# Cu                    8
# Na                    8
# B                     8
# HCO3                  8
# Cl                    8
# dtype: int64

# %%
df['Area (Acres)'].fillna(0,inplace=True)
df.dropna(inplace=True)

# %%
df
# Out:
#      Sr. No.  Report Number                   Farmer Name          Village  \
# 0        1.0          549.0     Surwade Pundalik Haribhau  Pimpalas Ramche
# 1        2.0          550.0      Surwade Mirabai Haribhau  Pimpalas Ramche
# 2        3.0          551.0      Surwade Haribhau Sitaram  Pimpalas Ramche
# 3        4.0          552.0      Surwade Haribhau Sitaram  Pimpalas Ramche
# 4        5.0          553.0  Tajane Madhukar Pandharinath  Pimpalas Ramche
# ..       ...            ...                           ...              ...
# 543    537.0         1260.0            Khode Tara Bhaskar         Jalalpur
# 544    538.0         1261.0       Vidhate Pavan Balasaheb         Chandshi
# 545    539.0         1262.0       Vidhate Pavan Balasaheb        Someshwar
# 546    540.0         1263.0       Vidhate Pavan Balasaheb          Talwade
# 547    541.0         1264.0         Tidke Manohar Vitthal          Talwade
#
#          Variety  Plot No/\nGat No Area (Acres) Sample Date Report Date    pH  \
# 0           RIES  A/B, (2.50 Acre)            0  07/09/2021  14/09/2021  8.47
# 1            SBL  A/B, (2.50 Acre)            0  07/09/2021  14/09/2021  7.91
# 2            SYR       (2.50 Acre)            0  07/09/2021  14/09/2021  8.07
# 3           RIES       (3.25 Acre)            0  07/09/2021  14/09/2021  8.19
# 4            SBL         3.00 Acre            0  07/09/2021  14/09/2021  8.14
# ..           ...               ...          ...         ...         ...   ...
# 543         TEMP         5.00 Acre            0  06/01/2022  11/01/2022  7.78
# 544          CBL         1.25 Acre            0  06/01/2022  11/01/2022  7.97
# 545          CBL         2.00 Acre            0  06/01/2022  11/01/2022  7.70
# 546          CBL         1.75 Acre            0  06/01/2022  11/01/2022  6.60
# 547    CAB + CHY  2.25 + 1.25 Acre            0  06/01/2022  11/01/2022  5.81
#
#      ...      Mg     S     Fe     Mn    Zn     Cu    Na      B   HCO3     Cl
# 0    ...   796.0  59.0  41.87   7.05  3.89   6.39  270.0  0.45  244.0  107.0
# 1    ...   756.0  41.0   8.04  25.40  3.14   4.89  215.0  0.25  183.0   88.0
# 2    ...   999.0  45.0  38.39   5.91  3.04   4.92  395.0  0.36  244.0   86.0
# 3    ...   928.0  47.0   6.84  23.37  3.96   9.21  270.0  0.37  305.0  133.0
# 4    ...   889.0  74.0   7.29   7.17  2.01   3.39  585.0  0.67  244.0  103.0
# ..   ...     ...   ...    ...    ...   ...    ...    ...   ...    ...    ...
# 543  ...  1037.0  21.0  18.00   4.59  2.67  13.02  160.0  0.14  181.0   96.0
# 544  ...  1163.0  22.0  13.47   4.71  2.51   8.58  140.0  0.23  244.0   83.0
# 545  ...   950.0  21.0  13.86   5.43  5.14   5.28  195.0  0.18  243.0   92.0
# 546  ...  1030.0  22.0  44.50  24.77  4.81  10.53  110.0  0.43  181.0   88.0
# 547  ...   900.0  21.0  54.16  26.20  9.34  21.55  130.0  0.16  183.0   84.0
#
# [511 rows x 28 columns]

# %%
v=df['Village'].unique()

# %%
df['Variety'].unique()
# Out:
# array(['  RIES', '  SBL', '  SYR', '  ZIN', '  CBL', '  TEMP', '  Muscat',
#        '  ZIN/CBL MIX', '  ZIN/TEMP', '  CAB', '  CHA', '  GRE', '  VIO',
#        '  SYR + GRE', '  SYR + ZIN', '  CHA + SYR', '  GRE + TEMP',
#        '  CBL + SYR', '  RIES+CBL+CBL+VIO', '  RIES + CBL', '  SYR + CBL',
#        '  UB', 'CAB', 'CBL', '  CAB + CBL', 'SYR + SYR', 'SYR',
#        'SYR+SYR+CAB', 'CAB + VIO', 'SBL + VIO', 'CAB + SYR',
#        '  TEMP + CBL', '  CBL+ TEMP', '  SYR + CAB', '  SYR + SBL',
#        '  TEMP + ZIN', '  SBL + TEMP', '  PNN', '  CBL + ZIN',
#        '  CHA + VIO', '  CBL + CHA', '  PNN + Muscat', '  CAB + CHY'],
#       dtype=object)

# %%
primary=["pH","P","K","S","N","NH4-N","EC","CaCo3","Ca","OC","Mg"]
#pH,N,P,K
secondary=["Fe","Mn","Zn","Cu","B","HCO3","Cl"]

# %%
p=[]
for i in primary[0:6]:
    p.append(round(df[df['Village']=="Pimpalas Ramche"][i].mean(),2))

# %%
s=[]
for i in secondary[0:6]:
    s.append(round(df[df['Village']=="Pimpalas Ramche"][i].mean(),2))

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = primary[0:6]

data = p

# Creating plot
fig = plt.figure(figsize =(9,17))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Macronutrients of soils')
# show plot
plt.show()

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = secondary[0:6]

data = s

# Creating plot
fig = plt.figure(figsize =(7,10))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Micronutrients of soils')
# show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import pearsonr
final=[]
for i in v:
    col=list(df.columns)
    cor=[]
    for p in primary:
        if p in col:
            f=[]
            for s in secondary:
                r=df.loc[df.Village==i]
                #r=r.iloc[::,9:]
                c=r[p].corr(r[s]).round(2)
                f.append(c)
            f.insert(0,p)
            f.insert(0,i)
            cor.append(f)
    final.append(cor)
secondary.insert(0,"Villages")
secondary.insert(1,"Chemical properties Available nutrients")

    #cor.insert(0,i)   
    #print(cor)
    #plt.figure(figsize=(10,10))
    #plot=sns.heatmap(r.corr().round(2),annot=True)
#final
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\DELL\anaconda3\lib\site-packages\numpy\lib\function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
fd=[]
for k in final:
    dp=pd.DataFrame(k)
    dp.columns=secondary
    fd.append(dp)
cd=pd.concat(fd)
cd


#dp.style.background_gradient(cmap='coolwarm')
#cd.to_excel("Correlation_of_soil_properties.xlsx",index=False)
#cd['Chemical properties Available nutrients'=='N']]]
# Out:
#            Villages Chemical properties Available nutrients    Fe    Mn    Zn  \
# 0   Pimpalas Ramche                                      pH  0.62 -0.29  0.37
# 1   Pimpalas Ramche                                       P -0.42  0.16 -0.17
# 2   Pimpalas Ramche                                       K  0.67 -0.62  0.44
# 3   Pimpalas Ramche                                       S -0.12 -0.61 -0.53
# 4   Pimpalas Ramche                                       N -0.37  0.63  0.52
# ..              ...                                     ...   ...   ...   ...
# 6           Talwade                                      EC -1.00 -1.00 -1.00
# 7           Talwade                                   CaCo3 -1.00 -1.00 -1.00
# 8           Talwade                                      Ca  1.00  1.00  1.00
# 9           Talwade                                      OC  1.00  1.00  1.00
# 10          Talwade                                      Mg -1.00 -1.00 -1.00
#
#       Cu     B  HCO3    Cl
# 0   0.42  0.07  0.60  0.56
# 1   0.20  0.04  0.40  0.22
# 2   0.29  0.29  0.39  0.28
# 3  -0.44  0.90  0.04  0.09
# 4   0.78 -0.40  0.50  0.58
# ..   ...   ...   ...   ...
# 6  -1.00  1.00 -1.00  1.00
# 7  -1.00  1.00 -1.00  1.00
# 8   1.00 -1.00  1.00 -1.00
# 9   1.00 -1.00  1.00 -1.00
# 10 -1.00  1.00 -1.00  1.00
#
# [1408 rows x 9 columns]

# %%
dp=pd.DataFrame(final[6])
dp.columns=secondary
dp.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_94a29_row0_col2, #T_94a29_row0_col3, #T_94a29_row1_col5, #T_94a29_row1_col7, #T_94a29_row1_col8, #T_94a29_row3_col6, #T_94a29_row4_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_94a29_row0_col4, #T_94a29_row6_col2, #T_94a29_row6_col3 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_94a29_row0_col5, #T_94a29_row0_col6, #T_94a29_row0_col7, #T_94a29_row0_col8, #T_94a29_row1_col2, #T_94a29_row1_col3, #T_94a29_row2_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_94a29_row1_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_94a29_row1_col6, #T_94a29_row6_col7, #T_94a29_row6_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_94a29_row2_col2, #T_94a29_row2_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_94a29_row2_col5 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_94a29_row2_col6 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_94a29_row2_col7, #T_94a29_row2_col8 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_94a29_row3_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_94a29_row3_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_94a29_row3_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_94a29_row3_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_94a29_row3_col7, #T_94a29_row3_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_94a29_row4_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_94a29_row4_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_94a29_row4_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_94a29_row4_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_94a29_row4_col7, #T_94a29_row4_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_94a29_row5_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_94a29_row5_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_94a29_row5_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_94a29_row5_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_94a29_row5_col6 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_94a29_row5_col7, #T_94a29_row5_col8, #T_94a29_row9_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_94a29_row6_col4 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_94a29_row6_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_94a29_row6_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_94a29_row7_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_94a29_row7_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_94a29_row7_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_94a29_row7_col5 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_94a29_row7_col6 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_94a29_row7_col7, #T_94a29_row7_col8 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_94a29_row8_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_94a29_row8_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_94a29_row8_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_94a29_row8_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_94a29_row8_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_94a29_row8_col7, #T_94a29_row8_col8 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_94a29_row9_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_94a29_row9_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_94a29_row9_col4 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_94a29_row9_col6 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_94a29_row9_col7, #T_94a29_row9_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_94a29_row10_col7, #T_94a29_row10_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# </style>
# <table id="T_94a29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94a29_level0_col0" class="col_heading level0 col0" >Villages</th>
#       <th id="T_94a29_level0_col1" class="col_heading level0 col1" >Chemical properties Available nutrients</th>
#       <th id="T_94a29_level0_col2" class="col_heading level0 col2" >Fe</th>
#       <th id="T_94a29_level0_col3" class="col_heading level0 col3" >Mn</th>
#       <th id="T_94a29_level0_col4" class="col_heading level0 col4" >Zn</th>
#       <th id="T_94a29_level0_col5" class="col_heading level0 col5" >Cu</th>
#       <th id="T_94a29_level0_col6" class="col_heading level0 col6" >B</th>
#       <th id="T_94a29_level0_col7" class="col_heading level0 col7" >HCO3</th>
#       <th id="T_94a29_level0_col8" class="col_heading level0 col8" >Cl</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94a29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94a29_row0_col0" class="data row0 col0" >Tisgaon</td>
#       <td id="T_94a29_row0_col1" class="data row0 col1" >pH</td>
#       <td id="T_94a29_row0_col2" class="data row0 col2" >-0.990000</td>
#       <td id="T_94a29_row0_col3" class="data row0 col3" >-0.980000</td>
#       <td id="T_94a29_row0_col4" class="data row0 col4" >0.620000</td>
#       <td id="T_94a29_row0_col5" class="data row0 col5" >0.990000</td>
#       <td id="T_94a29_row0_col6" class="data row0 col6" >0.870000</td>
#       <td id="T_94a29_row0_col7" class="data row0 col7" >0.980000</td>
#       <td id="T_94a29_row0_col8" class="data row0 col8" >0.980000</td>
#     </tr>
#     <tr>
#       <th id="T_94a29_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94a29_row1_col0" class="data row1 col0" >Tisgaon</td>
#       <td id="T_94a29_row1_col1" class="data row1 col1" >P</td>
#       <td id="T_94a29_row1_col2" class="data row1 col2" >0.770000</td>
#       <td id="T_94a29_row1_col3" class="data row1 col3" >0.790000</td>
#       <td id="T_94a29_row1_col4" class="data row1 col4" >0.060000</td>
#       <td id="T_94a29_row1_col5" class="data row1 col5" >-0.710000</td>
#       <td id="T_94a29_row1_col6" class="data row1 col6" >-0.500000</td>
#       <td id="T_94a29_row1_col7" class="data row1 col7" >-0.600000</td>
#       <td id="T_94a29_row1_col8" class="data row1 col8" >-0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_94a29_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94a29_row2_col0" class="data row2 col0" >Tisgaon</td>
#       <td id="T_94a29_row2_col1" class="data row2 col1" >K</td>
#       <td id="T_94a29_row2_col2" class="data row2 col2" >-0.940000</td>
#       <td id="T_94a29_row2_col3" class="data row2 col3" >-0.930000</td>
#       <td id="T_94a29_row2_col4" class="data row2 col4" >0.790000</td>
#       <td id="T_94a29_row2_col5" class="data row2 col5" >0.870000</td>
#       <td id="T_94a29_row2_col6" class="data row2 col6" >0.680000</td>
#       <td id="T_94a29_row2_col7" class="data row2 col7" >0.970000</td>
#       <td id="T_94a29_row2_col8" class="data row2 col8" >0.970000</td>
#     </tr>
#     <tr>
#       <th id="T_94a29_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94a29_row3_col0" class="data row3 col0" >Tisgaon</td>
#       <td id="T_94a29_row3_col1" class="data row3 col1" >S</td>
#       <td id="T_94a29_row3_col2" class="data row3 col2" >0.460000</td>
#       <td id="T_94a29_row3_col3" class="data row3 col3" >0.440000</td>
#       <td id="T_94a29_row3_col4" class="data row3 col4" >-0.020000</td>
#       <td id="T_94a29_row3_col5" class="data row3 col5" >-0.650000</td>
#       <td id="T_94a29_row3_col6" class="data row3 col6" >-0.820000</td>
#       <td id="T_94a29_row3_col7" class="data row3 col7" >-0.410000</td>
#       <td id="T_94a29_row3_col8" class="data row3 col8" >-0.410000</td>
#     </tr>
#     <tr>
#       <th id="T_94a29_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94a29_row4_co

# %%
cd['Fe'].fillna(cd['Fe'].mean(),inplace=True)
cd['Mn'].fillna(cd['Mn'].mean(),inplace=True)
cd['Zn'].fillna(cd['Zn'].mean(),inplace=True)
cd['Cu'].fillna(cd['Cu'].mean(),inplace=True)
cd['B'].fillna(cd['B'].mean(),inplace=True)
cd['HCO3'].fillna(cd['HCO3'].mean(),inplace=True)
cd['Cl'].fillna(cd['Cl'].mean(),inplace=True)
cd.isna().sum()
cd
# Out:
#            Villages Chemical properties Available nutrients    Fe    Mn    Zn  \
# 0   Pimpalas Ramche                                      pH  0.62 -0.29  0.37
# 1   Pimpalas Ramche                                       P -0.42  0.16 -0.17
# 2   Pimpalas Ramche                                       K  0.67 -0.62  0.44
# 3   Pimpalas Ramche                                       S -0.12 -0.61 -0.53
# 4   Pimpalas Ramche                                       N -0.37  0.63  0.52
# ..              ...                                     ...   ...   ...   ...
# 6           Talwade                                      EC -1.00 -1.00 -1.00
# 7           Talwade                                   CaCo3 -1.00 -1.00 -1.00
# 8           Talwade                                      Ca  1.00  1.00  1.00
# 9           Talwade                                      OC  1.00  1.00  1.00
# 10          Talwade                                      Mg -1.00 -1.00 -1.00
#
#       Cu     B  HCO3    Cl
# 0   0.42  0.07  0.60  0.56
# 1   0.20  0.04  0.40  0.22
# 2   0.29  0.29  0.39  0.28
# 3  -0.44  0.90  0.04  0.09
# 4   0.78 -0.40  0.50  0.58
# ..   ...   ...   ...   ...
# 6  -1.00  1.00 -1.00  1.00
# 7  -1.00  1.00 -1.00  1.00
# 8   1.00 -1.00  1.00 -1.00
# 9   1.00 -1.00  1.00 -1.00
# 10 -1.00  1.00 -1.00  1.00
#
# [1408 rows x 9 columns]

# %%
for i in range(5):
    cor=cd.iloc[i,2:].values.tolist()
    def addlabels(x,y):
        for i in range(len(x)):
            plt.text(i,y[i],y[i])

    if __name__ == '__main__':
    # creating data on which bar chart will be plot
        x = ["Fe","Mn","Zn","Cu","B","HCO3","Cl"]
        y = cor
        print(y)

        # making the bar chart on the data
        plt.bar(x, y)

        # calling the function to add value labels
        addlabels(x, y)

        # giving title to the plot
        plt.title("Corellation B/W Primary and Seconday Nutrients")

        # giving X and Y labels
        plt.xlabel(f"Primary Nutrient({primary[i]})")
        plt.ylabel("Seconday Nutrients")

        # visualizing the plot
        plt.show()
# Out:
# [0.62, -0.29, 0.37, 0.42, 0.07, 0.6, 0.56]
# [-0.42, 0.16, -0.17, 0.2, 0.04, 0.4, 0.22]
# [0.67, -0.62, 0.44, 0.29, 0.29, 0.39, 0.28]
# [-0.12, -0.61, -0.53, -0.44, 0.9, 0.04, 0.09]
# [-0.37, 0.63, 0.52, 0.78, -0.4, 0.5, 0.58]

# %% [markdown]
# # Categorization of soil parameters and nutrients

# %%
n=df.iloc[::,9:].columns
cpn=[]
for vl in v:
    high=[]
    low=[]
    medium=[]

    for i in n:
        r=df.loc[df.Village==vl]
        per_h=r[i].sum()/len(r)
        high.append(round(r[i].sum()/len(r),2))
        low.append(round(per_h-1.0,2))
        medium.append(str(round(per_h-1.0,2))+"-"+str(round(r[i].sum()/len(r),2)))
    cs=pd.DataFrame({"Village":vl,"Parameter":n,"LOW (Acidic)":low,"MEDIUM (Neutral)":medium,"HIGH (Alkaline)":high})
    cpn.append(cs)
pn=pd.concat(cpn)
pn
# Out:
#             Village Parameter  LOW (Acidic) MEDIUM (Neutral)  HIGH (Alkaline)
# 0   Pimpalas Ramche        pH          7.12        7.12-8.12             8.12
# 1   Pimpalas Ramche        EC         -0.74       -0.74-0.26             0.26
# 2   Pimpalas Ramche     CaCo3          7.83        7.83-8.83             8.83
# 3   Pimpalas Ramche        OC          0.12        0.12-1.12             1.12
# 4   Pimpalas Ramche         N        180.83    180.83-181.83           181.83
# ..              ...       ...           ...              ...              ...
# 14          Talwade        Cu         15.04      15.04-16.04            16.04
# 15          Talwade       Na         119.00      119.0-120.0           120.00
# 16          Talwade         B         -0.70         -0.7-0.3             0.30
# 17          Talwade      HCO3        181.00      181.0-182.0           182.00
# 18          Talwade        Cl         85.00        85.0-86.0            86.00
#
# [2432 rows x 5 columns]

# %% [markdown]
# # Nutrient properties of soils with mean values

# %%
cdf=[]
for cv in v:
    pr=['pH','N','P','K']
    m=df.loc[df.Village==cv]
    cp=[]
    for p in pr:
        mn=round(m[p].mean(),2)
        r=str(m[p].min())+"-"+str(m[p].max())
        cp.append([cv,p,r,mn])
    d2=pd.DataFrame(cp,columns=['Village','Chemical Property','Range',"Mean"])
    cdf.append(d2)
cs2=pd.concat(cdf)
cs2
# Out:
#             Village Chemical Property        Range    Mean
# 0   Pimpalas Ramche                pH    7.91-8.47    8.12
# 1   Pimpalas Ramche                 N  168.0-210.0  181.83
# 2   Pimpalas Ramche                 P    12.0-27.0   21.00
# 3   Pimpalas Ramche                 K  310.0-700.0  505.83
# 0              Oney                pH    7.91-8.42    8.16
# ..              ...               ...          ...     ...
# 3         Someshwar                 K  220.0-220.0  220.00
# 0           Talwade                pH     5.81-6.6    6.21
# 1           Talwade                 N  188.0-195.0  191.50
# 2           Talwade                 P    11.0-23.0   17.00
# 3           Talwade                 K  210.0-320.0  265.00
#
# [512 rows x 4 columns]

# %%
# Import libraries
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = cs2.iloc[0:4,1].values.tolist()

data = cs2.iloc[0:4,3].values.tolist()

# Creating plot
fig = plt.figure(figsize =(5, 7))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Nutrient  properties of soils')
# show plot
plt.show()

# %%
cdf2=[]
for cv in v:
    pr1=['Cu','Zn','Fe','Mn','B']
    m1=df.loc[df.Village==cv]
    cp=[]
    for p in pr1:
        mn=round(m1[p].mean(),2)
        r=str(m1[p].min())+"-"+str(m1[p].max())
        cp.append([cv,p,r,mn])
    d2=pd.DataFrame(cp,columns=['Village','Chemical Property','Range',"Mean"])
    cdf2.append(d2)
cs2=pd.concat(cdf2)
cs2
# Out:
#             Village Chemical Property        Range   Mean
# 0   Pimpalas Ramche                Cu    3.39-9.21   5.55
# 1   Pimpalas Ramche                Zn    2.01-3.96   3.23
# 2   Pimpalas Ramche                Fe   4.56-41.87  17.83
# 3   Pimpalas Ramche                Mn    5.91-25.4  12.69
# 4   Pimpalas Ramche                 B    0.25-0.67   0.46
# ..              ...               ...          ...    ...
# 0           Talwade                Cu  10.53-21.55  16.04
# 1           Talwade                Zn    4.81-9.34   7.07
# 2           Talwade                Fe   44.5-54.16  49.33
# 3           Talwade                Mn   24.77-26.2  25.48
# 4           Talwade                 B    0.16-0.43   0.29
#
# [640 rows x 4 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = cs2.iloc[0:4,1].values.tolist()

data = cs2.iloc[0:4,3].values.tolist()

# Creating plot
fig = plt.figure(figsize =(5, 7))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Nutrient properties of soils')
# show plot
plt.show()

# %% [markdown]
# # Percentage samples deficient micronutrients in soils

# %%
cdf2=[]
for cv in v:
    pr1=['Cu','Zn','Fe','Mn','B']
    m1=df.loc[df.Village==cv]
    cp=[]
    for p in pr1:
        mn=round(sum(m1[p])/len(df)*100,2)
        cp.append([cv,p,mn])
    d2=pd.DataFrame(cp,columns=['Village','Chemical Property',"Percentage"])
    cdf2.append(d2)
cs2=pd.concat(cdf2)
cs2
# Out:
#             Village Chemical Property  Percentage
# 0   Pimpalas Ramche                Cu        6.52
# 1   Pimpalas Ramche                Zn        3.79
# 2   Pimpalas Ramche                Fe       20.94
# 3   Pimpalas Ramche                Mn       14.90
# 4   Pimpalas Ramche                 B        0.54
# ..              ...               ...         ...
# 0           Talwade                Cu        6.28
# 1           Talwade                Zn        2.77
# 2           Talwade                Fe       19.31
# 3           Talwade                Mn        9.97
# 4           Talwade                 B        0.12
#
# [640 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
cars = cs2.iloc[0:4,1].values.tolist()

data = cs2.iloc[0:4,2].values.tolist()

# Creating plot
fig = plt.figure(figsize =(5, 7))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Percentage samples deficient micronutrients in soils')
# show plot
plt.show()

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
labelencoder_Y = LabelEncoder()
df['Y']= labelencoder_Y.fit_transform(df.iloc[:,3].values)
x = df.iloc[:, 9:28].values 
Y = df["Y"].values 
X=[]
for q in x:
    X.append([float(i) for i in q])
#Split the data again, but this time into 75% training and 25% testing data sets.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

    #Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

def models(X_train,Y_train):
    
    #Using Logistic Regression 
      from sklearn.linear_model import LogisticRegression
      log = LogisticRegression(random_state = 0)
      log.fit(X_train, Y_train)

      #Using KNeighborsClassifier 
      from sklearn.neighbors import KNeighborsClassifier
      knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
      knn.fit(X_train, Y_train)

      #Using SVC linear
      from sklearn.svm import SVC
      svc_lin = SVC(kernel = 'linear', random_state = 0)
      svc_lin.fit(X_train, Y_train)

      #Using SVC rbf
      from sklearn.svm import SVC
      svc_rbf = SVC(kernel = 'rbf', random_state = 0)
      svc_rbf.fit(X_train, Y_train)

      #Using GaussianNB 
      from sklearn.naive_bayes import GaussianNB
      gauss = GaussianNB()
      gauss.fit(X_train, Y_train)

      #Using DecisionTreeClassifier 
      from sklearn.tree import DecisionTreeClassifier
      tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
      tree.fit(X_train, Y_train)

      #Using RandomForestClassifier method of ensemble class to use Random Forest Classification algorithm
      from sklearn.ensemble import RandomForestClassifier
      forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
      forest.fit(X_train, Y_train)

      #print model accuracy on the training data.
      print('[0]Logistic Regression Training Accuracy:', log.score(X_train, Y_train))
      print('[1]K Nearest Neighbor Training Accuracy:', knn.score(X_train, Y_train))
      print('[2]Support Vector Machine (Linear Classifier) Training Accuracy:', svc_lin.score(X_train, Y_train))
      print('[3]Support Vector Machine (RBF Classifier) Training Accuracy:', svc_rbf.score(X_train, Y_train))
      print('[4]Gaussian Naive Bayes Training Accuracy:', gauss.score(X_train, Y_train))
      print('[5]Decision Tree Classifier Training Accuracy:', tree.score(X_train, Y_train))
      print('[6]Random Forest Classifier Training Accuracy:', forest.score(X_train, Y_train))

      return  log, knn, svc_lin, svc_rbf, gauss, tree, forest
model = models(X_train,Y_train)
    #Print Prediction of KNN model
pred_k = model[5].predict(X_test)
print('Prediction of KNN model',pred_k)
# Out:
# [0]Logistic Regression Training Accuracy: 0.7780678851174935
# [1]K Nearest Neighbor Training Accuracy: 0.4804177545691906
# [2]Support Vector Machine (Linear Classifier) Training Accuracy: 0.9608355091383812
# [3]Support Vector Machine (RBF Classifier) Training Accuracy: 0.46475195822454307
# [4]Gaussian Naive Bayes Training Accuracy: 0.8772845953002611
# [5]Decision Tree Classifier Training Accuracy: 1.0
# [6]Random Forest Classifier Training Accuracy: 0.9895561357702349
# Prediction of KNN model [ 24 126  47  45  61  48  66  48 126  83  85  65   3  50  92  93 111  86
#   44  18  50 105  14  70  98  99  92  90  44  70  28  28  48  92  48  93
#   27  86  66  26  22  75   3  90  22  93  86  26  27  26  90  42  86 102
#   50 127  90  70  90  74  90  78  52  96  48  85 111  90 123  90  24  15
#   65 102  98  81  51 120  96 126 110  84 106  90  90 126  61  50  24  48
#   15  34  88  45  44  83  90  25  90 119  39 115  17  90   8  61  77  14
#   66  90 104  70  89  44 126  68  78  68  93  90  22  93  93  48  93 120
#   27  14]

# %%
alg_model=pd.DataFrame({"Logistic Regression":model[0].predict(X_test),"KNN":model[1].predict(X_test),"SVM(L)":model[2].predict(X_test),"SVM(RBF)":model[3].predict(X_test),"GNB":model[4].predict(X_test),"DT":model[5].predict(X_test),"Random Forest":model[6].predict(X_test)})
a=round(alg_model.mean(),2)
av=a.values.tolist()
ac=list(alg_model.columns)

# %%
import pandas as pd
from matplotlib import pyplot as plt




# Figure Size
fig = plt.figure(figsize =(10, 7))

# Horizontal Bar Plot
plt.bar(ac, av)

# Show Plot
plt.show()

# %%
s=set(Y)
v1=df['Village'].values
data_dict=dict(zip(list(s), list(set(v1))))
z=[data_dict[w] for w in list(set(pred_k))]
result=pd.DataFrame({"Village":z,"Soil_Status":"Fertile"})

# %%
cars = ['Fertile','Not Fertile']

data = [len(result),len(data_dict)-len(result)]

# Creating plot
fig = plt.figure(figsize =(5, 7))
plt.pie(data, labels = cars,autopct='%1.1f%%')
plt.title('Percent soils Feritility')
# show plot
plt.show()
print(result)
# Out:
#               Village Soil_Status
# 0             Chandsi     Fertile
# 1               Shaha     Fertile
# 2      Vadner Bhairav     Fertile
# 3            Vilwandi     Fertile
# 4          Dongargaon     Fertile
# 5            Rasalpur     Fertile
# 6           Vehalgaon     Fertile
# 7             Harsule     Fertile
# 8            Nandgaon     Fertile
# 9          Pimpalnare     Fertile
# 10              Kalas     Fertile
# 11         Mahegaon D     Fertile
# 12          Musalgaon     Fertile
# 13         Sakore Mig     Fertile
# 14        Bharanewadi     Fertile
# 15         Dharangaon     Fertile
# 16    Pimpalas Ramche     Fertile
# 17            Sangavi     Fertile
# 18             Shirol     Fertile
# 19            Jakhori     Fertile
# 20          Lasalgaon     Fertile
# 21                Rui     Fertile
# 22             Manori     Fertile
# 23          Tamaswadi     Fertile
# 24         Deherewadi     Fertile
# 25              Manur     Fertile
# 26           Nandurdi     Fertile
# 27  Pimpalgaon Nipani     Fertile
# 28          Materwadi     Fertile
# 29         Baktharpur     Fertile
# 30              Ujani     Fertile
# 31   Pimpalgaon Khamb     Fertile
# 32       Umrale Khurd     Fertile
# 33            Nalwadi     Fertile
# 34           Dhakambe     Fertile
# 35             Dugaon     Fertile
# 36            Palkhed     Fertile
# 37            Tikondi     Fertile
# 38           Nandur M     Fertile
# 39          Vanasgaon     Fertile
# 40          Vanarwadi     Fertile
# 41           Dahiwadi     Fertile
# 42            Bharvas     Fertile
# 43          Umbarkhed     Fertile
# 44            Valkhed     Fertile
# 45             Adgaon     Fertile
# 46             Jevali     Fertile
# 47             Mukhed     Fertile
# 48           Bijaragi     Fertile
# 49               Pade     Fertile
# 50           Jalalpur     Fertile
# 51   Talegaon/Anjneri     Fertile
# 52             Patoda     Fertile
# 53          Janamatti     Fertile
# 54          Savargoan     Fertile
# 55        Lohshingave     Fertile
